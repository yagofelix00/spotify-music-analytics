# %% [markdown]
# # Spotify Music Analytics — Exploratory Data Analysis
#
# This notebook contains the exploratory data analysis of the processed Spotify datasets.
#
# Datasets:
# - artists
# - albums
# - tracks

# %% [markdown]
# ## 1. Imports

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load processed datasets

# %%
artists = pd.read_csv("../data/processed/artists.csv")
albums = pd.read_csv("../data/processed/albums.csv")
tracks = pd.read_csv("../data/processed/tracks.csv")

# %% [markdown]
# ## 3. Dataset overview

# %%
print("Artists:", artists.shape)
print("Albums:", albums.shape)
print("Tracks:", tracks.shape)
# Out:
# Artists: (5, 4)
# Albums: (93, 7)
# Tracks: (1566, 13)

# %% [markdown]
# ## 4. Sample records

# %%
artists.head()
# Out:
#                spotify_id          name    type  \
# 0  7dGJo4pcD2V6oG8kP0tJRR        Eminem  artist
# 1  6XyY86QOPPrYVGvF9ch6wz   Linkin Park  artist
# 2  0k17h0D3J5VfsdmQ1iZtE9    Pink Floyd  artist
# 3  0WwSkZ7LtFUFjGjMZBMt6T  Dire Straits  artist
# 4  0ECwFtbIWEVNwjlrfc6xoL        Eagles  artist
#
#                                          spotify_url
# 0  https://open.spotify.com/artist/7dGJo4pcD2V6oG...
# 1  https://open.spotify.com/artist/6XyY86QOPPrYVG...
# 2  https://open.spotify.com/artist/0k17h0D3J5Vfsd...
# 3  https://open.spotify.com/artist/0WwSkZ7LtFUFjG...
# 4  https://open.spotify.com/artist/0ECwFtbIWEVNwj...

# %%
albums.head()
# Out:
#                spotify_id                                               name  \
# 0  5DV2liMHX5AqtiLqy3Qu1b                    STANS (The Official Soundtrack)
# 1  2DQ6hHlAGj6DiT0Y068bnK         The Marshall Mathers LP (25th Anniversary)
# 2  31hcgCSu4mlA82syOFItur  The Death of Slim Shady (Coup De Grâce): Expan...
# 3  3kjHLu1pL7tdY88GFwEkl6            The Death of Slim Shady (Coup De Grâce)
# 4  5EUgcfO5OWxnniHR3QYFcK        The Marshall Mathers LP2 (Expanded Edition)
#
#                 artist_id artist_name album_type  total_tracks  \
# 0  7dGJo4pcD2V6oG8kP0tJRR      Eminem      album            12
# 1  7dGJo4pcD2V6oG8kP0tJRR      Eminem      album            20
# 2  7dGJo4pcD2V6oG8kP0tJRR      Eminem      album            23
# 3  7dGJo4pcD2V6oG8kP0tJRR      Eminem      album            19
# 4  7dGJo4pcD2V6oG8kP0tJRR      Eminem      album            27
#
#                                          spotify_url
# 0  https://open.spotify.com/album/5DV2liMHX5AqtiL...
# ...

# %%
tracks.head()
# Out:
#                spotify_id        name                album_id  \
# 0  0TR2EOv4irt7GAiLIZ3kZ8        Stan  5DV2liMHX5AqtiLqy3Qu1b
# 1  3VvxblbhUGyyBgdT7EQR0p     Bad Guy  5DV2liMHX5AqtiLqy3Qu1b
# 2  773Ls0jOd52jEzWh6Pc55U       Arose  5DV2liMHX5AqtiLqy3Qu1b
# 3  2hejwnTsNazjgnLFxnwvbF   Beautiful  5DV2liMHX5AqtiLqy3Qu1b
# 4  5lRcJDTuiLWQe0OkWNIfVS  Not Afraid  5DV2liMHX5AqtiLqy3Qu1b
#
#                         album_name               artist_id artist_name  \
# 0  STANS (The Official Soundtrack)  7dGJo4pcD2V6oG8kP0tJRR      Eminem
# 1  STANS (The Official Soundtrack)  7dGJo4pcD2V6oG8kP0tJRR      Eminem
# 2  STANS (The Official Soundtrack)  7dGJo4pcD2V6oG8kP0tJRR      Eminem
# 3  STANS (The Official Soundtrack)  7dGJo4pcD2V6oG8kP0tJRR      Eminem
# 4  STANS (The Official Soundtrack)  7dGJo4pcD2V6oG8kP0tJRR      Eminem
#
#    disc_number  track_number  duration_ms  explicit  \
# 0            1             1       404106      True
# 1            1             2       434358      True
# ...

# %% [markdown]
# ## 5. Dataset structure

# %%
artists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   spotify_id   5 non-null      object
#  1   name         5 non-null      object
#  2   type         5 non-null      object
#  3   spotify_url  5 non-null      object
# dtypes: object(4)
# memory usage: 292.0+ bytes

# %%
albums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   spotify_id    93 non-null     object
#  1   name          93 non-null     object
#  2   artist_id     93 non-null     object
#  3   artist_name   93 non-null     object
#  4   album_type    93 non-null     object
#  5   total_tracks  93 non-null     int64
#  6   spotify_url   93 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.2+ KB

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1566 entries, 0 to 1565
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   spotify_id        1566 non-null   object
#  1   name              1566 non-null   object
#  2   album_id          1566 non-null   object
#  3   album_name        1566 non-null   object
#  4   artist_id         1566 non-null   object
#  5   artist_name       1566 non-null   object
#  6   disc_number       1566 non-null   int64
#  7   track_number      1566 non-null   int64
#  8   duration_ms       1566 non-null   int64
#  9   explicit          1566 non-null   bool
#  10  spotify_url       1566 non-null   object
#  11  duration_seconds  1566 non-null   float64
#  12  duration_minutes  1566 non-null   float64
# dtypes: bool(1), float64(2), int64(3), object(7)
# memory usage: 148.5+ KB

# %% [markdown]
# ## 6. Summary

# %%
summary = pd.DataFrame(
    {
        "dataset": ["artists", "albums", "tracks"],
        "rows": [
            len(artists),
            len(albums),
            len(tracks),
        ],
        "columns": [
            artists.shape[1],
            albums.shape[1],
            tracks.shape[1],
        ],
    }
)

summary
# Out:
#    dataset  rows  columns
# 0  artists     5        4
# 1   albums    93        7
# 2   tracks  1566       13
